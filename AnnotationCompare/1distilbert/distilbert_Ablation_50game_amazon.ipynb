# %% [markdown]
# # Import

# %%
# !pip install datasets
# !pip install transformers[torch]
# !pip install optuna

# %%
import os
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer, BertForSequenceClassification
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from transformers import Trainer, TrainingArguments
from transformers import pipeline
from datasets import concatenate_datasets, load_dataset
from huggingface_hub import hf_hub_download
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datasets
from datasets import Dataset, Value, ClassLabel, Features
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from transformers import DataCollatorWithPadding
import optuna
from huggingface_hub import notebook_login
from sklearn.model_selection import StratifiedKFold

# lables value
# 2 = positive
# 1 = neutral
# 0 = negative

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Annotated reviews

# %%
# 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
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dataset = load_dataset("HFFErica/PublicDatasets", data_files={'train': 'DF9.csv', 'validation': 'DF10.csv'})
dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# DF9.csv:   0%|          | 0.00/138k [00:00<?, ?B/s]
# DF10.csv:   0%|          | 0.00/58.4k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 840
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 360
#     })
# })

# %%
test_dataset = load_dataset("HFFErica/TBSA_sentiment_round2", data_files={'test': 'test_df_imbalanced.csv'})
test_dataset
# Out:
# test_df_imbalanced.csv:   0%|          | 0.00/239k [00:00<?, ?B/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1972
#     })
# })

# %%
features = dataset["train"].features.copy()
features["label"] = ClassLabel(names=['negative', 'neutral', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch
label_dataset = dataset.map(adjust_labels, batched=True, features=features)

features = dataset["validation"].features.copy()
features["label"] = ClassLabel(names=['negative', 'neutral', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch
label_dataset = dataset.map(adjust_labels, batched=True, features=features)


features = test_dataset["test"].features.copy()
features["label"] = ClassLabel(names=['negative', 'neutral', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch
test_label_dataset = test_dataset.map(adjust_labels, batched=True, features=features)
# Out:
# Map:   0%|          | 0/840 [00:00<?, ? examples/s]
# Map:   0%|          | 0/360 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1972 [00:00<?, ? examples/s]

# %%
print(label_dataset["train"].shape)
print(label_dataset["validation"].shape)
print(test_label_dataset["test"].shape)
# Out:
# (840, 2)
# (360, 2)
# (1972, 2)

# %%
train_dataset = label_dataset['train']
validation_dataset = label_dataset['validation']
test_dataset = test_label_dataset['test']

# %%
print(train_dataset)
print(validation_dataset)
print(test_dataset)
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 840
# })
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 360
# })
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 1972
# })

# %%
train_dataset = train_dataset.map(lambda examples: {'labels': examples['label']}, batched=True)
validation_dataset = validation_dataset.map(lambda examples: {'labels': examples['label']}, batched=True)
test_dataset = test_dataset.map(lambda examples: {'labels': examples['label']}, batched=True)
# Out:
# Map:   0%|          | 0/840 [00:00<?, ? examples/s]
# Map:   0%|          | 0/360 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1972 [00:00<?, ? examples/s]

# %% [markdown]
# # Model

# %%
model_id="lxyuan/distilbert-base-multilingual-cased-sentiments-student"

label2id = {"positive": 2, "neutral": 1,"negative":0}
id2label = {"positive": 2, "neutral": 1,"negative":0}

model = AutoModelForSequenceClassification.from_pretrained(model_id,
                                                           num_labels=train_dataset.features["label"].num_classes,
                                                           id2label=id2label,
                                                           label2id=label2id,

                                                           ignore_mismatched_sizes=True)
tokenizer = AutoTokenizer.from_pretrained(model_id)
model.config
# Out:
# config.json:   0%|          | 0.00/759 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# DistilBertConfig {
#   "_name_or_path": "lxyuan/distilbert-base-multilingual-cased-sentiments-student",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "negative": 0,
#     "neutral": 1,
#     "positive": 2
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "negative": 0,
#     "neutral": 1,
#     "positive": 2
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.44.2",
#   "vocab_size": 119547
# }

# %%
MAX_LENGTH = 256
train_dataset = train_dataset.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
validation_dataset = validation_dataset.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
test_dataset = test_dataset.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
# Out:
# Map:   0%|          | 0/840 [00:00<?, ? examples/s]
# Map:   0%|          | 0/360 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1972 [00:00<?, ? examples/s]

# %%
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
validation_dataset.set_format(type='torch', columns=['input_ids',  'attention_mask', 'labels'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# # Hyperparameters search

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(model_id, return_dict=True)

# %%
from sklearn.metrics import f1_score
# Define a function to compute the F1 score
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    f1 = f1_score(labels, predictions, average='weighted')
    return {"f1": f1}

# %%
training_args = TrainingArguments("test",  eval_steps=500, disable_tqdm=True, do_eval=True, evaluation_strategy='steps')
trainer = Trainer(
    args=training_args,
    data_collator=DataCollatorWithPadding(tokenizer),
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    # eval_dataset=test_dataset,
    model_init=model_init,
    compute_metrics=compute_metrics,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
def hp_space_optuna(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 5e-5, log=True),
        "num_train_epochs": trial.suggest_int("num_train_epochs", 2, 4),
        "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [16, 32, 64]),
    }

# %%
best_run = trainer.hyperparameter_search(direction="maximize", hp_space=hp_space_optuna, n_trials=10)
print(f"Best run: {best_run}")
# Out:
# [I 2024-09-30 11:35:24,214] A new study created in memory with name: no-name-78b4d0be-3f98-47d8-b842-41f627d81035
# {'train_runtime': 67.4654, 'train_samples_per_second': 37.352, 'train_steps_per_second': 2.357, 'train_loss': 1.0333623346292748, 'epoch': 3.0}
# [I 2024-09-30 11:36:36,135] Trial 0 finished with value: 0.5277061116844398 and parameters: {'learning_rate': 1.5631201648402843e-05, 'num_train_epochs': 3, 'per_device_train_batch_size': 16}. Best is trial 0 with value: 0.5277061116844398.
# {'eval_loss': 0.95149827003479, 'eval_f1': 0.5277061116844398, 'eval_runtime': 3.0087, 'eval_samples_per_second': 119.655, 'eval_steps_per_second': 14.957, 'epoch': 3.0}
# {'train_runtime': 65.1486, 'train_samples_per_second': 38.681, 'train_steps_per_second': 2.441, 'train_loss': 0.9761613569919418, 'epoch': 3.0}
# [I 2024-09-30 11:37:44,802] Trial 1 finished with value: 0.5867181231620928 and parameters: {'learning_rate': 2.466796639778945e-05, 'num_train_epochs': 3, 'per_device_train_batch_size': 16}. Best is trial 1 with value: 0.5867181231620928.
# {'eval_loss': 0.8900153040885925, 'eval_f1': 0.5867181231620928, 'eval_runtime': 2.8314, 'eval_samples_per_second': 127.144, 'eval_steps_per_second': 15.893, 'epoch': 3.0}
# {'train_runtime': 86.8618, 'train_samples_per_second': 38.682, 'train_steps_per_second': 0.645, 'train_loss': 1.1035474368504115, 'epoch': 4.0}
# [I 2024-09-30 11:39:15,108] Trial 2 finished with value: 0.46456100183318766 and parameters: {'learning_rate': 1.76584110441269e-05, 'num_train_epochs': 4, 'per_device_train_batch_size': 64}. Best is trial 1 with value: 0.5867181231620928.
# {'eval_loss': 1.015182375907898, 'eval_f1': 0.46456100183318766, 'eval_runtime': 2.8327, 'eval_samples_per_second': 127.089, 'eval_steps_per_second': 15.886, 'epoch': 4.0}
# {'train_runtime': 69.1368, 'train_samples_per_second': 36.449, 'train_steps_per_second': 1.172, 'train_loss': 1.1126395331488714, 'epoch': 3.0}
# [I 2024-09-30 11:40:27,809] Trial 3 finished with value: 0.46561521089822977 and parameters: {'learning_rate': 1.3052550519389249e-05, 'num_train_epochs': 3, 'per_device_train_batch_size': 32}. Best is trial 1 with value: 0.5867181231620928.
# {'eval_loss': 1.0277817249298096, 'eval_f1': 0.46561521089822977, 'eval_runtime': 2.8544, 'eval_samples_per_second': 126.123, 'eval_steps_per_second': 15.765, 'epoch': 3.0}
# {'train_runtime': 84.4579, 'train_samples_per_second': 39.783, 'train_steps_per_second': 1.279, 'train_loss': 1.0597702308937356, 'epoch': 4.0}
# [I 2024-09-30 11:41:55,749] Trial 4 finished with value: 0.48365445511043564 and parameters: {'learning_rate': 1.4340754525525923e-05, 'num_train_epochs': 4, 'per_device_train_batch_size': 32}. Best is trial 1 with value: 0.5867181231620928.
# {'eval_loss': 0.9837072491645813, 'eval_f1': 0.48365445511043564, 'eval_runtime': 2.8387, 'eval_samples_per_second': 126.82, 'eval_steps_per_second': 15.853, 'epoch': 4.0}
# {'train_runtime': 43.6231, 'train_samples_per_second': 38.512, 'train_steps_per_second': 0.642, 'train_loss': 1.226529257638114, 'epoch': 2.0}
# [I 2024-09-30 11:42:43,048] Trial 5 finished with value: 0.3138583334299259 and parameters: {'learning_rate': 1.4870861302495252e-05, 'num_train_epochs': 2, 'per_device_train_batch_size': 64}. Best is trial 1 with value: 0.5867181231620928.
# {'eval_loss': 1.0993739366531372, 'eval_f1': 0.3138583334299259, 'eval_runtime': 2.9466, 'eval_samples_per_second': 122.175, 'eval_steps_per_second': 15.272, 'epoch': 2.0}
# {'train_runtime': 46.8297, 'train_samples_per_second': 35.875, 'train_steps_per_second': 2.264, 'train_loss': 1.0431026242813974, 'epoch': 2.0}
# [I 2024-09-30 11:43:33,435] Trial 6 finished with value: 0.4689529360691531 and parameters: {'learning_rate': 2.8209914088197337e-05, 'num_train_epochs': 2, 'per_device_train_batch_size': 16}. Best is trial 1 with value: 0.5867181231620928.
# {'eval_loss': 0.9453266859054565, 'eval_f1': 0.4689529360691531, 'eval_runtime': 2.8805, 'eval_samples_per_second': 124.979, 'eval_steps_per_second': 15.622, 'epoch': 2.0}
# {'train_runtime': 91.2633, 'train_samples_per_second': 36.817, 'train_steps_per_second': 2.323, 'train_loss': 0.7729341758871978, 'epoch': 4.0}
# [I 2024-09-30 11:45:08,179] Trial 7 finished with value: 0.681266589329988 and parameters: {'learning_rate': 4.585172978522198e-05, 'num_train_epochs': 4, 'per_device_train_batch_size': 16}. Best is trial 7 with value: 0.681266589329988.
# {'eval_loss': 0.8041194677352905, 'eval_f1': 0.681266589329988, 'eval_runtime': 2.8772, 'eval_samples_per_second': 125.12, 'eval_steps_per_second': 15.64, 'epoch': 4.0}
# {'train_runtime': 95.9474, 'train_samples_per_second': 35.019, 'train_steps_per_second': 2.21, 'train_loss': 0.9959212968934257, 'epoch': 4.0}
# [I 2024-09-30 11:46:47,791] Trial 8 finished with value: 0.5305339426649355 and parameters: {'learning_rate': 1.3452841786410243e-05, 'num_train_epochs': 4, 'per_device_train_batch_size': 16}. Best is trial 7 with value: 0.681266589329988.
# {'eval_loss': 0.9239153265953064, 'eval_f1': 0.5305339426649355, 'eval_runtime': 2.8357, 'eval_samples_per_second': 126.951, 'eval_steps_per_second': 15.869, 'epoch': 4.0}
# {'train_runtime': 69.5231, 'train_samples_per_second': 36.247, 'train_steps_per_second': 0.604, 'train_loss': 1.1658693949381511, 'epoch': 3.0}
# [I 2024-09-30 11:48:00,766] Trial 9 finished with value: 0.3960152839528576 and parameters: {'learning_rate': 1.4598010833806254e-05, 'num_train_epochs': 3, 'per_device_train_batch_size': 64}. Best is trial 7 with value: 0.681266589329988.
# {'eval_loss': 1.060792326927185, 'eval_f1': 0.3960152839528576, 'eval_runtime': 2.8293, 'eval_samples_per_second': 127.242, 'eval_steps_per_second': 15.905, 'epoch': 3.0}
# Best run: BestRun(run_id='7', objective=0.681266589329988, hyperparameters={'learning_rate': 4.585172978522198e-05, 'num_train_epochs': 4, 'per_device_train_batch_size': 16}, run_summary=None)

# %%
best_run
# Out:
# BestRun(run_id='7', objective=0.681266589329988, hyperparameters={'learning_rate': 4.585172978522198e-05, 'num_train_epochs': 4, 'per_device_train_batch_size': 16}, run_summary=None)

# %% [markdown]
# # Trainer

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
training_args = TrainingArguments(
    output_dir='./Best_game',          # output directory
    learning_rate= 4.585172978522198e-05,
    num_train_epochs=4,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=16,   # batch size for evaluation
    logging_dir='./logs',            # directory for storing logs
    logging_steps=100,
    do_train=True,
    do_eval=True,
    no_cuda=False,
    load_best_model_at_end=True,
    eval_steps=100,
    evaluation_strategy="steps"
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    compute_metrics=compute_metrics
)

train_out = trainer.train()
train_out
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='212' max='212' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [212/212 01:26, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.994700</td>
#       <td>0.881159</td>
#       <td>0.608333</td>
#       <td>0.597584</td>
#       <td>0.608139</td>
#       <td>0.608333</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.596800</td>
#       <td>0.803845</td>
#       <td>0.677778</td>
#       <td>0.673315</td>
#       <td>0.673832</td>
#       <td>0.677778</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=212, training_loss=0.7729339734563287, metrics={'train_runtime': 89.2212, 'train_samples_per_second': 37.659, 'train_steps_per_second': 2.376, 'total_flos': 222549198520320.0, 'train_loss': 0.7729339734563287, 'epoch': 4.0})

# %% [markdown]
# # CM

# %%
def plot_confusion_matrix(y_preds, y_true, labels):
#     cm = confusion_matrix(y_true, y_preds)
    cm = confusion_matrix(y_true, y_preds, normalize="true")
    fig, ax = plt.subplots(figsize=(10, 10))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap="Blues", values_format=".2f", ax=ax, colorbar=False)
    plt.title("confusion matrix")
    plt.show()

# %%
y_valid = np.array(test_dataset["label"])
preds_output = trainer.predict(test_dataset)
preds_output.metrics
# Out:
# {'test_loss': 1.159631609916687,
#  'test_accuracy': 0.5856997971602435,
#  'test_f1': 0.5444594512683943,
#  'test_precision': 0.5633950104736734,
#  'test_recall': 0.5687490883923816,
#  'test_runtime': 14.4229,
#  'test_samples_per_second': 136.727,
#  'test_steps_per_second': 8.597}

# %%
y_preds = np.argmax(preds_output.predictions, axis=1)
labels = train_dataset.features["label"].names
plot_confusion_matrix(y_preds, y_valid, labels)

# %%
def plot_confusion_matrix(y_preds, y_true, labels):
    cm = confusion_matrix(y_true, y_preds)
    # cm = confusion_matrix(y_true, y_preds, normalize="true")
    fig, ax = plt.subplots(figsize=(10, 10))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap="Blues", values_format=".2f", ax=ax, colorbar=False)
    plt.title("confusion matrix")
    plt.show()

# %%
y_valid = np.array(test_dataset["label"])
preds_output = trainer.predict(test_dataset)
preds_output.metrics
# Out:
# {'test_loss': 1.159631609916687,
#  'test_accuracy': 0.5856997971602435,
#  'test_f1': 0.5444594512683943,
#  'test_precision': 0.5633950104736734,
#  'test_recall': 0.5687490883923816,
#  'test_runtime': 14.4336,
#  'test_samples_per_second': 136.626,
#  'test_steps_per_second': 8.591}

# %%
y_preds = np.argmax(preds_output.predictions, axis=1)
labels = train_dataset.features["label"].names
plot_confusion_matrix(y_preds, y_valid, labels)
